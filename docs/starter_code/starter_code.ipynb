# %%
#import libraries
from pandas import pandas as pd
import datetime

# %%
#read data into dataframe
data = pd.read_csv("..\..\Resources\cities.csv") 

data.set_index("City_ID", inplace=True)

# %%
#verify
data.head()
# Out:
#               City    Lat     Lng  Max Temperature (F)  Humidity (%)  \
# City_ID
# 0           Albany  42.60  -73.97                 79.0            66
# 1        Jamestown  42.10  -79.24                 75.0            73
# 2          Mataura -46.19  168.86                 39.0            83
# 3           Barrow  71.29 -156.79                 35.6            93
# 4         Klaksvík  62.23   -6.59                 57.2            71
#
#          Cloudiness (%)  Wind Speed (mph) Country    Datetime
# City_ID
# 0                    12              3.04      US  1592577607
# 1                    40              4.70      US  1592577743
# 2                   100              3.00      NZ  1592577743
# 3                    90             12.75      US  1592577743
# 4                    84              9.17      FO  1592577744

# %%
# render dataframe as html
html = data.to_html()

#verify
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temperature (F)</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed (mph)</th>
#       <th>Country</th>
#       <th>Datetime</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Albany</td>
#       <td>42.60</td>
#       <td>-73.97</td>
#       <td>79.00</td>
#       <td>66</td>
#       <td>12</td>
#       <td>3.04</td>
#       <td>US</td>
#       <td>1592577607</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jamestown</td>
#       <td>42.10</td>
#       <td>-79.24</td>
#       <td>75.00</td>
#       <td>73</td>
# ...

# %%
#write html to file
text_file = open("..\Data.html", "w", encoding="utf-8")
text_file.write(html)
text_file.close()
